# %%
import matplotlib.pyplot  as plt
import pandas as pd
from sklearn import tree 
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ### **Load Data**

# %%
df = pd.read_csv("data/Smartphone_Usage_And_Addiction_Analysis_7500_Rows.csv")
df.head()
# Out:
#   transaction_id user_id  age gender  daily_screen_time_hours  \
# 0       TXN00001  U00001   21   Male                     3.23
# 1       TXN00002  U00002   24  Other                     5.09
# 2       TXN00003  U00003   31  Other                     6.06
# 3       TXN00004  U00004   32  Other                     7.83
# 4       TXN00005  U00005   25   Male                     9.96
#
#    social_media_hours  gaming_hours  work_study_hours  sleep_hours  \
# 0                2.01          0.89              4.55         7.55
# 1                3.81          2.24              4.44         7.66
# 2                1.36          3.83              2.35         4.92
# 3                5.85          1.51              3.54         8.23
# 4                5.92          3.42              5.27         6.21
#
#    notifications_per_day  app_opens_per_day  weekend_screen_time stress_level  \
# 0                    248                154                 3.95       Medium
# ...

# %%
df.dtypes
# Out:
# transaction_id                 str
# user_id                        str
# age                          int64
# gender                         str
# daily_screen_time_hours    float64
# social_media_hours         float64
# gaming_hours               float64
# work_study_hours           float64
# sleep_hours                float64
# notifications_per_day        int64
# app_opens_per_day            int64
# weekend_screen_time        float64
# stress_level                   str
# academic_work_impact           str
# addiction_level                str
# addicted_label               int64
# dtype: object

# %%
def checkCategories(df, column):
    display(df[column].unique())

# %%
checkCategories(df, 'age') #  binary
# Out:
# array([21, 24, 31, 32, 25, 26, 35, 34, 27, 33, 19, 18, 20, 28, 22, 23, 29,
#        30])

# %%
checkCategories(df, "gender")
# Out:
# <ArrowStringArray>
# ['Male', 'Other', 'Female']
# Length: 3, dtype: str

# %%
# encoding the dataset
gender_map = {'Female':0, 'Male':1 , 'Other':2}
df['gender'] = df['gender'].map(gender_map)

# %%
label_encoder = LabelEncoder()
df['day'] =label_encoder.fit_transform(df['age'])

# %%
checkCategories(df, 'gender')  # categorical but it is ordinal
# Out:
# array([1, 2, 0])

# %%
# encoding the dataset
phone_usage_map = {'No':0, 'Yes':1,}
df['gender'] = df['gender'].map(phone_usage_map)

# %%
df.dtypes
# Out:
# transaction_id                 str
# user_id                        str
# age                          int64
# gender                     float64
# daily_screen_time_hours    float64
# social_media_hours         float64
# gaming_hours               float64
# work_study_hours           float64
# sleep_hours                float64
# notifications_per_day        int64
# app_opens_per_day            int64
# weekend_screen_time        float64
# stress_level                   str
# academic_work_impact           str
# addiction_level                str
# addicted_label               int64
# day                          int64
# dtype: object

# %% [markdown]
# #### **Get the independent and dependent features**

# %%
df.head()
# Out:
#   transaction_id user_id  age  gender  daily_screen_time_hours  \
# 0       TXN00001  U00001   21     NaN                     3.23
# 1       TXN00002  U00002   24     NaN                     5.09
# 2       TXN00003  U00003   31     NaN                     6.06
# 3       TXN00004  U00004   32     NaN                     7.83
# 4       TXN00005  U00005   25     NaN                     9.96
#
#    social_media_hours  gaming_hours  work_study_hours  sleep_hours  \
# 0                2.01          0.89              4.55         7.55
# 1                3.81          2.24              4.44         7.66
# 2                1.36          3.83              2.35         4.92
# 3                5.85          1.51              3.54         8.23
# 4                5.92          3.42              5.27         6.21
#
#    notifications_per_day  app_opens_per_day  weekend_screen_time stress_level  \
# 0                    248                154                 3.95       Medium
# ...

# %% [markdown]
# #### **Feature importance**

# %%
features = ['age', 'daily_screen_time_hours', 'social_media_hours', 'gaming_hours', 'work_study_hours', 'sleep_hours',]
X = df[features]

# %%
X = df[features]
X.head()
# Out:
#    age  daily_screen_time_hours  social_media_hours  gaming_hours  \
# 0   21                     3.23                2.01          0.89
# 1   24                     5.09                3.81          2.24
# 2   31                     6.06                1.36          3.83
# 3   32                     7.83                5.85          1.51
# 4   25                     9.96                5.92          3.42
#
#    work_study_hours  sleep_hours
# 0              4.55         7.55
# 1              4.44         7.66
# 2              2.35         4.92
# 3              3.54         8.23
# 4              5.27         6.21

# %%
y = df['age']
y.head()
# Out:
# 0    21
# 1    24
# 2    31
# 3    32
# 4    25
# Name: age, dtype: int64

# %% [markdown]
# #### **Splitting data into train and test**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=50)

# %% [markdown]
# #### **Get an instance of our Model**

# %%
model = tree.DecisionTreeClassifier(
    max_depth=4,
    min_samples_leaf=50,
    random_state=42 
    
)

model
# Out:
# DecisionTreeClassifier(max_depth=4, min_samples_leaf=50, random_state=42)

# %% [markdown]
# #### **Fit the model**

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, min_samples_leaf=50, random_state=42)

# %%
y_train.head()
y_train.dtype
# Out:
# dtype('int64')

# %%
y_train.count
# Out:
# <bound method Series.count of 3430    20
# 7248    22
# 6181    32
# 446     25
# 1564    35
#         ..
# 7457    29
# 6253    35
# 1931    23
# 5600    32
# 5808    33
# Name: age, Length: 5250, dtype: int64>

# %% [markdown]
# ### **Visual Representation**

# %%
plt.figure(figsize = (24,16))
tree.plot_tree(model, feature_names=features,  filled=True, fontsize=12)
plt.show()

# %% [markdown]
# #### **Run a prediction**

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([26, 31, 20, ..., 26, 26, 21], shape=(2250,))

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100}%")
# Out:
# Accuracy: 62.4%
