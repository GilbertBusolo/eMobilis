# %% [markdown]
# # Business Understanding
#
# This dataset include data for the estimation of obesity levels in individuals from the countries of Mexico, Peru and Colombia, based on their eating habits and physical condition.
#
# ** Additional Information **
#
# This dataset include data for the estimation of obesity levels in individuals from the countries of Mexico, Peru and Colombia, based on their eating habits and physical condition. The data contains 17 attributes and 2111 records, the records are labeled with the class variable NObesity (Obesity Level), that allows classification of the data using the values of Insufficient Weight, Normal Weight, Overweight Level I, Overweight Level II, Obesity Type I, Obesity Type II and Obesity Type III. 77% of the data was generated synthetically using the Weka tool and the SMOTE filter, 23% of the data was collected directly from users through a web platform.
#
# [Source](https://archive.ics.uci.edu/dataset/544/estimation+of+obesity+levels+based+on+eating+habits+and+physical+condition)

# %% [markdown]
# ## ** Data Understanding **
# - Head and tail (printing out the first 5 or few defined entries and the last entries)
# - shape (dimensions)
# - columns
# - datatypes
# - info
# - Missing Values
# - Duplicates
# - describe stats numerical  - mean | median | mode
# - describe stats categorical  - count | percentages
# - Visualizations

# %% [markdown]
# ## ** Load Libraries **

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt
import seaborn as sns

# %%
## ** Load Dataset **
obesity_level_df = pd.read_csv("data/ObesityDataSet_raw_and_data_sinthetic.csv")

# %% [markdown]
# #### **Get a glimpse of the data(head, tail)**

# %%
obesity_level_df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
obesity_level_df.tail()
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O SCC       FAF       TUE  \
# 2106  yes   3.0  3.0  Sometimes    no  1.728139  no  1.676269  0.906247
# 2107  yes   3.0  3.0  Sometimes    no  2.005130  no  1.341390  0.599270
# 2108  yes   3.0  3.0  Sometimes    no  2.054193  no  1.414209  0.646288
# 2109  yes   3.0  3.0  Sometimes    no  2.852339  no  1.139107  0.586035
# 2110  yes   3.0  3.0  Sometimes    no  2.863513  no  1.026452  0.714137
#
#            CALC                 MTRANS        NObeyesdad
# ...

# %% [markdown]
# ## ** Dimension Shape, Info, Data Types and Columns **

# %%
records, features = obesity_level_df.shape
output = f" Obesty Levels Data set is comprised of {records} records and {features} features"
print(output)
# Out:
#  Obesty Levels Data set is comprised of 2111 records and 17 features

# %%
obesity_level_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   str
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   str
#  5   FAVC                            2111 non-null   str
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   str
#  9   SMOKE                           2111 non-null   str
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   str
# ...

# %%
obesity_level_df.dtypes
# Out:
# Gender                                str
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight        str
# FAVC                                  str
# FCVC                              float64
# NCP                               float64
# CAEC                                  str
# SMOKE                                 str
# CH2O                              float64
# SCC                                   str
# FAF                               float64
# TUE                               float64
# CALC                                  str
# MTRANS                                str
# NObeyesdad                            str
# dtype: object

# %%
obesity_level_df.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='str')

# %% [markdown]
# ## ** Insights **
# - Obesty Levels Data set is comprised of 2111 records and 17 features
# - the dataset has two data types: float64(8) and str(9)

# %% [markdown]
# ## ** Check for Duplicates and Missing Values **

# %%
obesity_level_df.isna() .sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
obesity_level_df.duplicated() .sum()
# Out:
# np.int64(24)

# %% [markdown]
# ## ** Insight: **
# - The obesity dataset has no missing values
# - The dataset has 24 duplicate data

# %% [markdown]
# ## **Data Cleaning to Remove Duplicated Data**

# %%
duplicate_count = obesity_level_df.duplicated().sum() # View number of exact duplicates
print("Exact duplicates:", duplicate_count)
# Out:
# Exact duplicates: 24

# %%
exact_dupes = obesity_level_df[obesity_level_df.duplicated(keep=False)] # View list of all duplicates
print(exact_dupes)
# Out:
#      Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 97   Female  21.0    1.52    42.0                             no   no   3.0
# 98   Female  21.0    1.52    42.0                             no   no   3.0
# 105  Female  25.0    1.57    55.0                             no  yes   2.0
# 106  Female  25.0    1.57    55.0                             no  yes   2.0
# 145    Male  21.0    1.62    70.0                             no  yes   2.0
# 174    Male  21.0    1.62    70.0                             no  yes   2.0
# 179    Male  21.0    1.62    70.0                             no  yes   2.0
# 184    Male  21.0    1.62    70.0                             no  yes   2.0
# 208  Female  22.0    1.69    65.0                            yes  yes   2.0
# 209  Female  22.0    1.69    65.0                            yes  yes   2.0
# 282  Female  18.0    1.62    55.0                            yes  yes   2.0
# ...

# %%
obesity_level_df = obesity_level_df.drop_duplicates(keep='first') # removes the  duplicates

# %%
duplicate_count = obesity_level_df.duplicated().sum() # Confirms duplicates are removed
print("Exact duplicates:", duplicate_count)
# Out:
# Exact duplicates: 0

# %% [markdown]
# ## ** Descriptive Stats **

# %%
obesity_level_df.values
# Out:
# array([['Female', 21.0, 1.62, ..., 'no', 'Public_Transportation',
#         'Normal_Weight'],
#        ['Female', 21.0, 1.52, ..., 'Sometimes', 'Public_Transportation',
#         'Normal_Weight'],
#        ['Male', 23.0, 1.8, ..., 'Frequently', 'Public_Transportation',
#         'Normal_Weight'],
#        ...,
#        ['Female', 22.524036, 1.752206, ..., 'Sometimes',
#         'Public_Transportation', 'Obesity_Type_III'],
#        ['Female', 24.361936, 1.73945, ..., 'Sometimes',
#         'Public_Transportation', 'Obesity_Type_III'],
#        ['Female', 23.664709, 1.738836, ..., 'Sometimes',
#         'Public_Transportation', 'Obesity_Type_III']],
#       shape=(2087, 17), dtype=object)

# %%
obesity_level_df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2087.000000  2087.000000  2087.000000  2087.000000  2087.000000
# mean     24.353090     1.702674    86.858730     2.421466     2.701179
# std       6.368801     0.093186    26.190847     0.534737     0.764614
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.915937     1.630178    66.000000     2.000000     2.697467
# 50%      22.847618     1.701584    83.101100     2.396265     3.000000
# 75%      26.000000     1.769491   108.015907     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2087.000000  2087.000000  2087.000000
# mean      2.004749     1.012812     0.663035
# std       0.608284     0.853475     0.608153
# min       1.000000     0.000000     0.000000
# 25%       1.590922     0.124505     0.000000
# 50%       2.000000     1.000000     0.630866
# ...

# %%
sns.histplot(obesity_level_df, kde=True)
plt.title("Obesity Levels")
plt.show()

# %%
sns.histplot(obesity_level_df['Age'], kde=True)

plt.title("Obesity Levels by Age")
plt.show()

# %%
sns.histplot(obesity_level_df['Height'], kde=True)

plt.title("Obesity Levels by Height")
plt.show()

# %%
sns.histplot(obesity_level_df['Weight'], kde=True)

plt.title("Obesity Levels by Weight")
plt.show()

# %%
user_types = ['Weight', 'Age']
values = [obesity_level_df['Weight'].mean(), obesity_level_df['Age'].mean()]

plt.bar(user_types, values)

plt.title("Obesity Levels by Weight, Height and Age")
plt.xlabel("User Type")
plt.ylabel("Average Number of Rentals")

plt.show()
