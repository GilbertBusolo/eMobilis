# %% [markdown]
# # Business Understanding
#
# This dataset contains the hourly and daily count of rental bikes between years 2011 and 2012 in Capital bikeshare system with the corresponding weather and seasonal information.
#
# ** Additional Information **
#
# Bike sharing systems are new generation of traditional bike rentals where whole process from membership, rental and return back has become automatic. Through these systems, user is able to easily rent a bike from a particular position and return back at another position. Currently, there are about over 500 bike-sharing programs around the world which is composed of over 500 thousands bicycles. Today, there exists great interest in these systems due to their important role in traffic, environmental and health issues.
#
# Apart from interesting real world applications of bike sharing systems, the characteristics of data being generated by these systems make them attractive for the research. Opposed to other transport services such as bus or subway, the duration of travel, departure and arrival position is explicitly recorded in these systems. This feature turns bike sharing system into a virtual sensor network that can be used for sensing mobility in the city. Hence, it is expected that most of important events in the city could be detected via monitoring these data.
#
# [source]()

# %% [markdown]
# ## ** Data Understanding **
# - Head and tail (printing out the first 5 or few defined entries and the last entries)
# - shape (dimensions)
# - columns
# - datatypes
# - info
# - Missing Values
# - Duplicates
# - describe stats numerical  - mean | median | mode
# - describe stats categorical  - count | percentages
# - Visualizations

# %% [markdown]
# ## **Load Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt
import seaborn as sns

# %% [markdown]
# ## **Load Dataset**

# %%
day_df = pd.read_csv("data/bike+sharing+dataset/day.csv") # Loading day dataset

# %%
hour_df = pd.read_csv("data/bike+sharing+dataset/hour.csv") # Loading hour dataset

# %% [markdown]
# ## ** Glimpse of the Data **

# %%
day_df.head() # Glimpse of day head dataset
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
day_df.tail() # Glimpse of day tail dataset
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 726           2  0.254167  0.226642  0.652917   0.350133     247        1867
# 727           2  0.253333  0.255046  0.590000   0.155471     644        2451
# 728           2  0.253333  0.242400  0.752917   0.124383     159        1182
# 729           1  0.255833  0.231700  0.483333   0.350754     364        1432
# 730           2  0.215833  0.223487  0.577500   0.154846     439        2290
#
#       cnt
# 726  2114
# 727  3095
# 728  1341
# 729  1796
# ...

# %%
hour_df.head() # Glimpse of hour  head dataset
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
hour_df.tail() # Glimpse of hour  tail dataset
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 17374           1           2  0.26  0.2576  0.60     0.1642      11
# 17375           1           2  0.26  0.2576  0.60     0.1642       8
# 17376           1           1  0.26  0.2576  0.60     0.1642       7
# 17377           1           1  0.26  0.2727  0.56     0.1343      13
# 17378           1           1  0.26  0.2727  0.65     0.1343      12
#
#        registered  cnt
# 17374         108  119
# 17375          81   89
# 17376          83   90
# 17377          48   61
# 17378          37   49

# %% [markdown]
# ## ** Dimension Shape, Info, Data Types and Columns **

# %%
# Day Dataset
records, features = day_df.shape
output = f" Day Data set is comprised of {records} records and {features} features"
print(output)
# Out:
#  Day Data set is comprised of 731 records and 16 features

# %%
# Hour Dataset
records, features = hour_df.shape
output = f" Hour Data set is comprised of {records} records and {features} features"
print(output)
# Out:
#  Hour Data set is comprised of 17379 records and 17 features

# %%
day_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    str
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), str(1)
# memory usage: 91.5 KB

# %%
hour_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  str
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), str(1)
# memory usage: 2.3 MB

# %%
day_df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='str')

# %%
hour_df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='str')

# %%
hour_df.dtypes
# Out:
# instant         int64
# dteday            str
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %% [markdown]
# ## ** Insights **
# - There are 3 data types:
#     - int64  - 64 bit integer
#     - float64 - 64 bit floating point number
#     - str - Type string

# %%
day_df.dtypes
# Out:
# instant         int64
# dteday            str
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %% [markdown]
# ## ** Insights **
# - There are 4 data types:
#     - int64  - 64 bit integer
#     - float64 - 64 bit floating point number
#     - str - Type string
#     - object - Type object

# %% [markdown]
# ## ** Duplicates and Missing Values**

# %%
day_df.isna().sum() # No Missing Values
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
hour_df.isna().sum() # No Missing Values
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
day_df.duplicated().sum() # No duplicated values
# Out:
# np.int64(0)

# %%
hour_df.duplicated().sum() # No duplicated values
# Out:
# np.int64(0)

# %% [markdown]
# ## ** Descriptive Stats - Categorical and Numerical**

# %%
day_df.values
# Out:
# array([[1, '2011-01-01', 1, ..., 331, 654, 985],
#        [2, '2011-01-02', 1, ..., 131, 670, 801],
#        [3, '2011-01-03', 1, ..., 120, 1229, 1349],
#        ...,
#        [729, '2012-12-29', 1, ..., 159, 1182, 1341],
#        [730, '2012-12-30', 1, ..., 364, 1432, 1796],
#        [731, '2012-12-31', 1, ..., 439, 2290, 2729]],
#       shape=(731, 16), dtype=object)

# %%
hour_df.values
# Out:
# array([[1, '2011-01-01', 1, ..., 3, 13, 16],
#        [2, '2011-01-01', 1, ..., 8, 32, 40],
#        [3, '2011-01-01', 1, ..., 5, 27, 32],
#        ...,
#        [17377, '2012-12-31', 1, ..., 7, 83, 90],
#        [17378, '2012-12-31', 1, ..., 13, 48, 61],
#        [17379, '2012-12-31', 1, ..., 12, 37, 49]],
#       shape=(17379, 17), dtype=object)

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# ## ** Insights **
#
# ** Day - Count: **
# - Day Data set is comprised of 731 records and 16 features
# - The average daily rides are around 4,504.348837
# - The rides vary around the average by a standard deviation of 1,937.211452
# - The lowest recorded day had a count of 22 rides (min)
# - The highest recorded day has 8,714 rides (max)
# - 25% of days had below 3,152 rides
# - 50% of the days had around 4,548 rides
# - 75% of days had below 5,956 rides
#
# ** Hour:**
# - Hour Data set is comprised of 17379 records and 17 features
# - The mean hourly rides are around 189.463088
# - The rides vary around the average by a standard deviation of 181.387599
# - The lowest recorded hour had a count of 1 ride (min)
# - The highest recorded hour has 977 rides (max)
# - 25% of hours observed had below 142 rides
# - 50% of the hours observed had around 281 rides
# - 75% of hours observed had below 977 rides

# %% [markdown]
# ## ** Visializations **

# %%
hour_df.describe(include='object')
# Out:
# /var/folders/0c/1j_h2q_d3cz5xx15_x7nbdyw0000gn/T/ipykernel_3601/655880730.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   hour_df.describe(include='object')
#             dteday
# count        17379
# unique         731
# top     2011-01-01
# freq            24

# %%
day_df.groupby("season")["cnt"].mean().plot(kind="line")

plt.title("Average Bike Rentals by Season")
plt.xlabel("Season")
plt.ylabel("Count(No.)")
plt.show()

# %%
day_df.groupby("mnth")["cnt"].mean().plot(kind="line")

plt.title("Average Bike Rentals by Month")
plt.xlabel("Month")
plt.ylabel("Count(No.)")
plt.show()

# %%
sns.histplot(day_df['temp'], kde=True)

plt.title("Temperature Distribution vs Count")
plt.show()

# %%
hour_df.groupby("season")["cnt"].mean().plot(kind="line")

plt.title("Average Bike Rentals by Season and Count")
plt.xlabel("Season")
plt.ylabel("Count(No.)")
plt.show()

# %%
sns.histplot(day_df['registered'], kde=True)

plt.title("Registered Users Distribution vs Count")
plt.show()

# %%
sns.histplot(day_df['casual'], kde=True)

plt.title("Registered Casual Users vs Count")
plt.show()

# %%
# Day Dataset
user_types = ['Casual', 'Registered']
values = [day_df['casual'].mean(), day_df['registered'].mean()]

plt.bar(user_types, values)

plt.title("Average Bike Rentals for Casual vs Registered Users")
plt.xlabel("User Type")
plt.ylabel("Average Number of Rentals")

plt.show()

# %%
# Hour Dataset
user_types = ['Casual', 'Registered']
values = [hour_df['casual'].mean(), day_df['registered'].mean()]

plt.bar(user_types, values)

plt.title("Average Bike Rentals for Casual vs Registered Users")
plt.xlabel("User Type")
plt.ylabel("Average Number of Rentals")

plt.show()

# %%
# Hour Dataset
hour_df.groupby("season")["cnt"].mean().plot(kind="bar")

plt.title("Average Bike Rentals by Season - Hour")
plt.xlabel("Season")
plt.ylabel("Average Rentals")
plt.show()

# %%
# Day Dataset

day_df.groupby("season")["cnt"].mean().plot(kind="bar")

plt.title("Average Bike Rentals by Season - Hour")
plt.xlabel("Season")
plt.ylabel("Average Rentals")
plt.show()
